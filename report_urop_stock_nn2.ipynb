# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path("data/notebooks")

# %%
metrics = pd.read_csv(DATA_DIR / "metrics_all_symbols.csv")
rmse_pivot = pd.read_csv(DATA_DIR / "rmse_pivot_table.csv")
summary = pd.read_csv(DATA_DIR / "returns_summary_stats.csv", index_col=0)
metrics.head()

# %%
# Already encoded: Naive wins everywhere, but you can confirm
best_by_symbol = rmse_pivot.set_index("Symbol")[["LSTM","MA 5 day","MA 20 day","Naive lag1"]].idxmin(axis=1)
best_by_symbol.value_counts()

# %%
from IPython.display import Image, display

for fname in ["universe_normalized_prices.png",
              "corr_heatmap.png",
              "fig_AAPL_test_models.png",
              "fig_SPY_test_models.png",
              "fig_QQQ_test_models.png"]:
    display(Image(filename=DATA_DIR / fname))
